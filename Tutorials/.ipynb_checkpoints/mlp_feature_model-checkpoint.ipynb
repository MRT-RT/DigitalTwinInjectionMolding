# %% [markdown]
# #  Prädiktion der Bauteilqualität aus Prozessgrößenfeatures

# %% [markdown]
# Ziel ist es ein statisches polynomiales Modell zu bestimmen, welches die eingestellen Maschinenparameter auf die resultierende Bauteilqualität abbildet.
#
# Die für das Modelltraining (Schätzung der Modellparameter) und die Modellvalidierung zu verwendenden Daten wurden im Rahmen eines umfangreichen Versuchsplanes erhoben. Der Trainingsdatensatz umfasst die Daten von 2105 Produktionszyklen, der Validierungsdatensatz umfasst die Daten von 548 Produktionszyklen

# %%
import casadi as cs
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data_train = pkl.load(open('feat_data_train.pkl','rb'))
data_val= pkl.load(open('feat_data_val.pkl','rb'))

# %% [markdown]
# Plotte Ausgangsgröße (Bauteilqualität) des Trainings- und Validierungsdatensatzes

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.stripplot(x=data_train['charge'],y=data_train['Durchmesser_innen'],color='grey',alpha=.8,size=15,ax=ax)
sns.stripplot(x=data_val['charge'],y=data_val['Durchmesser_innen'],size=15,ax=ax)
ax.set_xlim([1,40]) # Zeige nur Teil des Plots da man sonst nicht viel erkennen kann
# Out:
# (1.0, 40.0)

# %% [markdown]
# Definiere zu identifizierendes Modell as CasADi-Funktion

# %%
W_h = cs.MX.sym('W_h',1,8)
b_h = cs.MX.sym('b_h',1,1)

W_o = theta1 = cs.MX.sym('W_o',1,1)
b_o = cs.MX.sym('b_o',1,1)


theta = cs.vcat([W_h.reshape((-1,1)),b_h,W_o.reshape((-1,1)),b_o])

u = cs.MX.sym('u',8,1)

h = cs.tanh(cs.mtimes(W_h,u)+b_h)
y = cs.mtimes(W_o,h)+b_o



f_model = cs.Function('f_model',[u,theta],[y],['u','theta'],['y'])

# %% [markdown]
# Werte Modell auf den Trainingsdaten aus und baue die Kostenfunktion auf

# %%
L = 0

u_label=['T_wkz_0', 'T_wkz_max', 't_Twkz_max', 'T_wkz_int', 'p_wkz_max','p_wkz_int', 'p_wkz_res', 't_pwkz_max']

y_label = ['Durchmesser_innen']

for k in data_train.index:
    u_k = data_train.loc[k][u_label].values.reshape((8,))
    
    y_k = data_train.loc[k][y_label]
    
    y_hat = f_model(u=u_k, theta=theta)['y']
    L = L + 0.5*(y_hat - y_k)**2

# %%
# Out:
# MX(@1=vertcat(W_h', b_h, W_o, b_o), ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((0.5*sq((f_model([53.827, 106.555, 1.38, 74279.2, 403.015, 15532.6, 0.0294827, 1.04], @1){0}-27.351)))+(0.5*sq((f_model([56.1159, 107.913, 1.44, 76530.3, 337.51, 11027.5, 0, 1.12], @1){0}-27.309))))+(0.5*sq((f_model([57.8326, 109.18, 1.46, 78067.4, 335.145, 10871.8, 0, 1.12], @1){0}-27.307))))+(0.5*sq((f_model([57.3519, 108.745, 1.42, 77321, 330.743, 10826.9, 0, 1.12], @1){0}-27.313))))+(0.5*sq((f_model([57.8707, 109.554, 1.42, 78331.3, 330.415, 10794.4, 0, 1.12], @1){0}-27.279))))+(0.5*sq((f_model([55.9938, 107.906, 1.4, 76592.1, 310.376, 9645.82, 0, 1.14], @1){0}-27.294))))+(0.5*sq((f_model([57.3672, 109.622, 1.4, 77791.1, 321.676, 10606.4, 0.438741, 1.14], @1){0}-27.289))))+(0.5*sq((f_model([58.0081, 109.668, 1.42, 78329.6, 325.093, 11341.1, 0.964794, 1.14], @1){0}-27.292))))+(0.5*sq((f_model([53.6973, 106.349, 0.84, 78623, 750.118, 45622.2, 8.49199, 0.32], @1){0}-27.837))))+(0.5*sq((f_model([56.0167, 111.66, 0.84, 81866.6, 730.276, 60364.7, 6.80325, 0.34], @1){0}-27.79))))+(0.5*sq((f_model([57.9546, 113.094, 0.84, 83752.2, 735.335, 58568.3, 5.16026, 0.34], @1){0}-27.748))))+(0.5*sq((f_model([58.5421, 113.239, 0.88, 84095.4, 735.729, 61744.3, 6.87411, 0.34], @1){0}-27.709))))+(0.5*sq((f_model([58.4506, 113.399, 0.8, 84400.9, 731.787, 61826.7, 6.88207, 0.34], @1){0}-27.687))))+(0.5*sq((f_model([59.0762, 113.697, 0.82, 84862, 739.54, 61704, 7.25949, 0.34], @1){0}-27.676))))+(0.5*sq((f_model([59.0228, 113.887, 0.88, 84907.5, 727.319, 62076.1, 7.38415, 0.34], @1){0}-27.658))))+(0.5*sq((f_model([59.3432, 114.017, 0.82, 85085, 737.306, 63038, 8.48945, 0.34], @1){0}-27.657))))+(0.5*sq((f_model([56.2609, 108.425, 1.32, 97636.9, 608.465, 27440.3, 0.419284, 0.9], @1){0}-27.566))))+(0.5*sq((f_model([56.9628, 109.272, 1.38, 98842.7, 648.543, 34546.8, 2.81698, 0.9], @1){0}-27.564))))+(0.5*sq((f_model([57.474, 109.546, 1.4, 99139.8, 655.573 ...

# %% [markdown]
# Initialisiere Struktur des Optimierungsproblems

# %%
nlp = {'x':theta, 'f':L}
S = cs.nlpsol('S', 'ipopt', nlp)

theta_init = np.random.normal(0,1,(11,1))

r=S(theta_init)

theta_opt = r['x']
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_14932/1828874499.py in <module>
#       4 theta_init = np.random.normal(0,1,(11,1))
#       5
# ----> 6 r=S(theta_init)
#       7
#       8 theta_opt = r['x']
#
# ~/anaconda3/envs/py38/lib/python3.9/site-packages/casadi/casadi.py in __call__(self, *args, **kwargs)
#   13442       if len(args)>0:
#   13443     # Ordered inputs -> return tuple
# > 13444         ret = self.call(args)
#   13445         if len(ret)==0:
#   13446           return None
#
# ~/anaconda3/envs/py38/lib/python3.9/site-packages/casadi/casadi.py in call(self, *args)
#   12322
#   12323         """
# > 12324         return _casadi.Function_call(self, *args)
#   12325
#   12326
#
# RuntimeError: .../casadi/core/function_internal.hpp:1241: Assertion "arg.size()==n_in_" failed:
# Incorrect number of inputs: Expected 8, got 1

# %% [markdown]
# Werte das trainierte Modell auf den Trainingsdaten aus

# %%
y_hat = []

for k in data_train.index:
    u_k = data_train.loc[k][u_label].values.reshape((8,1))
    
    y_k = data_train.loc[k][y_label]
    
    y_hat.append(float(f_model(u=u_k, theta=theta_opt)['y']))
    
data_train = data_train.assign(y_hat=y_hat)

# %%
Werte das trainierte Modell auf den Validierungsdaten aus

# %%
y_hat = []

for k in data_val.index:
    u_k = data_val.loc[k][u_label].values.reshape((8,1))
    
    y_k = data_val.loc[k][y_label]
    
    y_hat.append(float(f_model(u=u_k, theta=theta_opt)['y']))
    
data_val = data_val.assign(y_hat=y_hat)

# %% [markdown]
# Plotte wahre und prädizierte Bauteilqualität auf dem Trainingsdatensatz

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.stripplot(x=data_train['charge'],y=data_train['Durchmesser_innen'],color='grey',alpha=.8,size=15,ax=ax)
sns.stripplot(x=data_train['charge'],y=data_train['y_hat'],size=15,ax=ax)
ax.set_xlim([1,5]) # Zeige nur Teil des Plots da man sonst nicht viel erkennen kann
# Out:
# (1.0, 5.0)

# %%
Plotte wahre und prädizierte Bauteilqualität auf dem Trainingsdatensatz

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.stripplot(x=data_val['charge'],y=data_val['Durchmesser_innen'],color='grey',alpha=.8,size=15,ax=ax)
sns.stripplot(x=data_val['charge'],y=data_val['y_hat'],size=15,ax=ax)
ax.set_xlim([1,10]) # Zeige nur Teil des Plots da man sonst nicht viel erkennen kann

# %%
theta_init
# Out:
# array([[-0.79699624],
#        [ 1.5638384 ],
#        [-1.4154362 ],
#        [-0.80414302],
#        [-0.10047598],
#        [-0.14383337],
#        [-0.44340708],
#        [-1.79835912],
#        [ 0.88064662],
#        [-0.42262114],
#        [-0.51038132]])
